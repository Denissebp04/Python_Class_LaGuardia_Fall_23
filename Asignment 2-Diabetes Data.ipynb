# %%
#import libraries needed
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
#import data frame 
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
pd.set_option('display.max_columns',None) 
pd.set_option('display.max_rows',None)

# %%
#show first 300 rows of dataframe
df.head(300)
# Out:
#      encounter_id  patient_nbr             race  gender       age weight  \
# 0         2278392      8222157        Caucasian  Female    [0-10)      ?
# 1          149190     55629189        Caucasian  Female   [10-20)      ?
# 2           64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3          500364     82442376        Caucasian    Male   [30-40)      ?
# 4           16680     42519267        Caucasian    Male   [40-50)      ?
# 5           35754     82637451        Caucasian    Male   [50-60)      ?
# 6           55842     84259809        Caucasian    Male   [60-70)      ?
# 7           63768    114882984        Caucasian    Male   [70-80)      ?
# 8           12522     48330783        Caucasian  Female   [80-90)      ?
# 9           15738     63555939        Caucasian  Female  [90-100)      ?
# 10          28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 11          36900     77391171  AfricanAmerican    Male   [60-70)      ?
# ...

# %%
#show last 300 rows
df.tail(300)
# Out:
#         encounter_id  patient_nbr             race  gender       age  \
# 101466     439649102     95297031        Caucasian  Female   [80-90)
# 101467     439663286     61377795        Caucasian  Female   [80-90)
# 101468     439675868     41220999         Hispanic    Male  [90-100)
# 101469     439687376    174246125         Hispanic  Female   [60-70)
# 101470     439690214    164798069  AfricanAmerican  Female   [60-70)
# 101471     439693370    180768560        Caucasian    Male   [70-80)
# 101472     439693604    184455590        Caucasian  Female   [80-90)
# 101473     439705934     40475232        Caucasian  Female   [80-90)
# 101474     439709132    109758042         Hispanic    Male   [50-60)
# 101475     439709180     92802699        Caucasian  Female  [90-100)
# 101476     439709192     88660782        Caucasian    Male   [50-60)
# 101477     439709198     43407999        Caucasian  Female   [50-60)
# 101478     439709222    179930291        Caucasian    Male   [60-70)
# ...

# %%
#show how many rows and columns dataframe has
df.shape
# Out:
# (101766, 50)

# %%
#show statistics of data
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
#how many rows we have in our dataframe
df.count()
# Out:
# encounter_id                101766
# patient_nbr                 101766
# race                        101766
# gender                      101766
# age                         101766
# weight                      101766
# admission_type_id           101766
# discharge_disposition_id    101766
# admission_source_id         101766
# time_in_hospital            101766
# payer_code                  101766
# medical_specialty           101766
# num_lab_procedures          101766
# num_procedures              101766
# num_medications             101766
# number_outpatient           101766
# number_emergency            101766
# number_inpatient            101766
# diag_1                      101766
# diag_2                      101766
# diag_3                      101766
# number_diagnoses            101766
# max_glu_serum               101766
# A1Cresult                   101766
# metformin                   101766
# repaglinide                 101766
# nateglinide                 101766
# ...

# %%
df1=df.drop(['weight','payer_code'],axis=1)
df1.head(20)
# Out:
#     encounter_id  patient_nbr             race  gender       age  \
# 0        2278392      8222157        Caucasian  Female    [0-10)
# 1         149190     55629189        Caucasian  Female   [10-20)
# 2          64410     86047875  AfricanAmerican  Female   [20-30)
# 3         500364     82442376        Caucasian    Male   [30-40)
# 4          16680     42519267        Caucasian    Male   [40-50)
# 5          35754     82637451        Caucasian    Male   [50-60)
# 6          55842     84259809        Caucasian    Male   [60-70)
# 7          63768    114882984        Caucasian    Male   [70-80)
# 8          12522     48330783        Caucasian  Female   [80-90)
# 9          15738     63555939        Caucasian  Female  [90-100)
# 10         28236     89869032  AfricanAmerican  Female   [40-50)
# 11         36900     77391171  AfricanAmerican    Male   [60-70)
# 12         40926     85504905        Caucasian  Female   [40-50)
# ...

# %%
pd.set_option('display.max_columns',None) 
pd.set_option('display.max_rows',None) 
df2=df1.drop('medical_specialty',axis=1)
df2.head(25)
# Out:
#     encounter_id  patient_nbr             race  gender       age  \
# 0        2278392      8222157        Caucasian  Female    [0-10)
# 1         149190     55629189        Caucasian  Female   [10-20)
# 2          64410     86047875  AfricanAmerican  Female   [20-30)
# 3         500364     82442376        Caucasian    Male   [30-40)
# 4          16680     42519267        Caucasian    Male   [40-50)
# 5          35754     82637451        Caucasian    Male   [50-60)
# 6          55842     84259809        Caucasian    Male   [60-70)
# 7          63768    114882984        Caucasian    Male   [70-80)
# 8          12522     48330783        Caucasian  Female   [80-90)
# 9          15738     63555939        Caucasian  Female  [90-100)
# 10         28236     89869032  AfricanAmerican  Female   [40-50)
# 11         36900     77391171  AfricanAmerican    Male   [60-70)
# 12         40926     85504905        Caucasian  Female   [40-50)
# ...

# %%
df3=df2.drop(df2.index[[0]])
df3.head(25)
# Out:
#     encounter_id  patient_nbr             race  gender       age  \
# 1         149190     55629189        Caucasian  Female   [10-20)
# 2          64410     86047875  AfricanAmerican  Female   [20-30)
# 3         500364     82442376        Caucasian    Male   [30-40)
# 4          16680     42519267        Caucasian    Male   [40-50)
# 5          35754     82637451        Caucasian    Male   [50-60)
# 6          55842     84259809        Caucasian    Male   [60-70)
# 7          63768    114882984        Caucasian    Male   [70-80)
# 8          12522     48330783        Caucasian  Female   [80-90)
# 9          15738     63555939        Caucasian  Female  [90-100)
# 10         28236     89869032  AfricanAmerican  Female   [40-50)
# 11         36900     77391171  AfricanAmerican    Male   [60-70)
# 12         40926     85504905        Caucasian  Female   [40-50)
# 13         42570     77586282        Caucasian    Male   [80-90)
# ...

# %%
df3.groupby(['race'])['diabetesMed'].count()
# Out:
# race
# ?                   2273
# AfricanAmerican    19210
# Asian                641
# Caucasian          76098
# Hispanic            2037
# Other               1506
# Name: diabetesMed, dtype: int64

# %%
df4=df3[df3['race']=='Caucasian']
df4.head(25)
# Out:
#     encounter_id  patient_nbr       race  gender       age  admission_type_id  \
# 1         149190     55629189  Caucasian  Female   [10-20)                  1
# 3         500364     82442376  Caucasian    Male   [30-40)                  1
# 4          16680     42519267  Caucasian    Male   [40-50)                  1
# 5          35754     82637451  Caucasian    Male   [50-60)                  2
# 6          55842     84259809  Caucasian    Male   [60-70)                  3
# 7          63768    114882984  Caucasian    Male   [70-80)                  1
# 8          12522     48330783  Caucasian  Female   [80-90)                  2
# 9          15738     63555939  Caucasian  Female  [90-100)                  3
# 12         40926     85504905  Caucasian  Female   [40-50)                  1
# 13         42570     77586282  Caucasian    Male   [80-90)                  1
# 17         84222    108662661  Caucasian  Female   [50-60)                  1
# ...

# %%
df5=df4[df4['diabetesMed']=='Yes']
df6=df5[['race', 'gender','diabetesMed']]
df6.head(25)
# Out:
#          race  gender diabetesMed
# 1   Caucasian  Female         Yes
# 3   Caucasian    Male         Yes
# 4   Caucasian    Male         Yes
# 5   Caucasian    Male         Yes
# 6   Caucasian    Male         Yes
# 7   Caucasian    Male         Yes
# 8   Caucasian  Female         Yes
# 9   Caucasian  Female         Yes
# 12  Caucasian  Female         Yes
# 13  Caucasian    Male         Yes
# 17  Caucasian  Female         Yes
# 26  Caucasian    Male         Yes
# 27  Caucasian  Female         Yes
# 28  Caucasian    Male         Yes
# 29  Caucasian  Female         Yes
# 32  Caucasian  Female         Yes
# 33  Caucasian    Male         Yes
# 34  Caucasian  Female         Yes
# 35  Caucasian  Female         Yes
# 36  Caucasian  Female         Yes
# 37  Caucasian  Female         Yes
# 38  Caucasian    Male         Yes
# 39  Caucasian    Male         Yes
# 40  Caucasian  Female         Yes
# 41  Caucasian    Male         Yes

# %%
df6.count()
# Out:
# race           58450
# gender         58450
# diabetesMed    58450
# dtype: int64

# %%
df6 = df3.loc[(df['race'] == 'Caucasian') | (df['race'] == 'AfricanAmerican')]
df6

# %%
df7=df6[df6['diabetesMed']=='Yes']
df7.count()

# %%
df7=df3[df3['race']=='AfricanAmerican']
df7.head(25)
# Out:
#     encounter_id  patient_nbr             race  gender      age  \
# 2          64410     86047875  AfricanAmerican  Female  [20-30)
# 10         28236     89869032  AfricanAmerican  Female  [40-50)
# 11         36900     77391171  AfricanAmerican    Male  [60-70)
# 14         62256     49726791  AfricanAmerican  Female  [60-70)
# 15         73578     86328819  AfricanAmerican    Male  [60-70)
# 16         77076     92519352  AfricanAmerican    Male  [50-60)
# 18         89682    107389323  AfricanAmerican    Male  [70-80)
# 22        182796     63000108  AfricanAmerican  Female  [70-80)
# 24        216156     62718876  AfricanAmerican  Female  [70-80)
# 30        253380     56480238  AfricanAmerican  Female  [60-70)
# 31        253722     96664626  AfricanAmerican    Male  [70-80)
# 50        550098     21820806  AfricanAmerican    Male  [50-60)
# 52        590346     37746639  AfricanAmerican  Female  [40-50)
# 53        591996     58497651  AfricanAmerican  Female  [50-60)
# ...

# %%
df8=df7[df7['diabetesMed']=='Yes']
df9=df8[['race','gender','diabetesMed']]
df9.head(25)
# Out:
#                 race  gender diabetesMed
# 2    AfricanAmerican  Female         Yes
# 10   AfricanAmerican  Female         Yes
# 11   AfricanAmerican    Male         Yes
# 14   AfricanAmerican  Female         Yes
# 15   AfricanAmerican    Male         Yes
# 16   AfricanAmerican    Male         Yes
# 18   AfricanAmerican    Male         Yes
# 24   AfricanAmerican  Female         Yes
# 30   AfricanAmerican  Female         Yes
# 31   AfricanAmerican    Male         Yes
# 52   AfricanAmerican  Female         Yes
# 53   AfricanAmerican  Female         Yes
# 56   AfricanAmerican  Female         Yes
# 58   AfricanAmerican  Female         Yes
# 60   AfricanAmerican  Female         Yes
# 62   AfricanAmerican  Female         Yes
# 64   AfricanAmerican  Female         Yes
# 76   AfricanAmerican    Male         Yes
# 88   AfricanAmerican    Male         Yes
# 92   AfricanAmerican    Male         Yes
# 93   AfricanAmerican  Female         Yes
# 94   AfricanAmerican  Female         Yes
# ...

# %%
df9.count()
# Out:
# race           14798
# gender         14798
# diabetesMed    14798
# dtype: int64

# %%
df10=df4[['race', 'age','num_medications']]
df10.head(25)
# Out:
#          race       age  num_medications
# 1   Caucasian   [10-20)               18
# 3   Caucasian   [30-40)               16
# 4   Caucasian   [40-50)                8
# 5   Caucasian   [50-60)               16
# 6   Caucasian   [60-70)               21
# 7   Caucasian   [70-80)               12
# 8   Caucasian   [80-90)               28
# 9   Caucasian  [90-100)               18
# 12  Caucasian   [40-50)               15
# 13  Caucasian   [80-90)               31
# 17  Caucasian   [50-60)               11
# 23  Caucasian   [80-90)               19
# 26  Caucasian   [80-90)               18
# 27  Caucasian   [50-60)               11
# 28  Caucasian   [20-30)               20
# 29  Caucasian   [80-90)               14
# 32  Caucasian   [70-80)               16
# 33  Caucasian   [60-70)               18
# 34  Caucasian   [70-80)               20
# 35  Caucasian   [60-70)               11
# 36  Caucasian   [70-80)                8
# 37  Caucasian   [60-70)               12
# ...

# %%
df10.mean()
# Out:
# C:\Users\16466\AppData\Local\Temp/ipykernel_13272/4218645827.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df10.mean()
# num_medications    16.285934
# dtype: float64

# %%
df10.count()
# Out:
# race               76098
# gender             76098
# num_medications    76098
# dtype: int64

# %%
df11=df7[['race','age','num_medications']]
df11.head(25)
# Out:
#                race      age  num_medications
# 2   AfricanAmerican  [20-30)               13
# 10  AfricanAmerican  [40-50)               17
# 11  AfricanAmerican  [60-70)               11
# 14  AfricanAmerican  [60-70)                2
# 15  AfricanAmerican  [60-70)               13
# 16  AfricanAmerican  [50-60)               17
# 18  AfricanAmerican  [70-80)               23
# 22  AfricanAmerican  [70-80)               12
# 24  AfricanAmerican  [70-80)               18
# 30  AfricanAmerican  [60-70)               18
# 31  AfricanAmerican  [70-80)               10
# 50  AfricanAmerican  [50-60)               14
# 52  AfricanAmerican  [40-50)               17
# 53  AfricanAmerican  [50-60)               11
# 56  AfricanAmerican  [50-60)               19
# 58  AfricanAmerican  [80-90)               21
# 60  AfricanAmerican  [70-80)               15
# 62  AfricanAmerican  [40-50)               15
# 64  AfricanAmerican  [50-60)               16
# ...

# %%
df11.mean()
# Out:
# C:\Users\16466\AppData\Local\Temp/ipykernel_13272/2236868547.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df11.mean()
# race               19210
# gender             19210
# num_medications    19210
# dtype: int64

# %%
df11.count()
# Out:
# race               19210
# gender             19210
# num_medications    19210
# dtype: int64

# %%
import seaborn as sns

# %%
sns.histplot(data=df3,
            x='num_medications',
            binwidth=5,
            kde=True).set_title('Number of Medications')
plt.show()

# %%
sns.histplot(data=df3,
            x='num_medications',
            binwidth=5,
            kde=True,
            hue='age').set_title('Number of Medications by Age Group')
plt.show()

# %%
df12 = pd.DataFrame({'num_medications': [10, 20, 30, 40, 50, 60, 70, 80],
                   'age': ['[30-40]', '[30-40]', '[30-40]', '[30-40]', '[70-80]', '[70-80]', '[70-80]', '[70-80]']})
sns.boxplot(data=df3, x='age', y='num_medications').set(title='Number of Medications by Age Group')
# Out:
# [Text(0.5, 1.0, 'Number of Medications by Age Group')]

# %% [markdown]
# # Conclusion

# %% [markdown]
# For this project I started by getting the information of my dataframe first by doing some descriptive analytics using functions such as describe, count,and shape among others. After that, I did some data cleaning by dropping some columns that were not useful for me such as the "Weight" column since its information was missing. Then, I moved into filtering my data to get a little more specific. In order to get more specific I decided to look into the Caucasian and African American groups and how many take diabetes medication and their number of medications. Lastly, I created some visualizations based on the number of medications per age group. From my results it looks that more Caucasians take diabetes medication than African Americans, however, I do not believe this is necessarily accurate since the amount of Caucasians in this dataframe is significantly larger than the amount of African Americans.
