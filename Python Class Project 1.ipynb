# %%
3+4
# Out:
# 7

# %%
(3.14)*(5**2)
# Out:
# 78.5

# %%
role=input('What are you ')
print('you are a',role)
# Out:
# What are you student
# you are a student

# %%
def BMI (H, W):
    bmi= W/((H)**2)
    return bmi

person1= BMI(1.65,60)
person2=BMI(1.75,75)
print(person1)
print(person2)
# Out:
# 22.03856749311295
# 24.489795918367346

# %% [markdown]
# # PROJECT 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.count()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64

# %%
df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
df1=df[df['School Name']=='P.S. 034 Franklin D. Roosevelt']

# %%
df1
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54234      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54235      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54236      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54238      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54239      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54240      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# ...

# %%
df1.describe()
# Out:
#               Year  Total Tested
# count    29.000000     29.000000
# mean   2015.931034      5.000000
# std       0.842235      4.191829
# min    2015.000000      1.000000
# 25%    2015.000000      2.000000
# 50%    2016.000000      3.000000
# 75%    2017.000000      7.000000
# max    2017.000000     16.000000

# %%
df1_new=df1.drop('Number Scoring CR', axis=1)
df1_N=df1_new.drop('Percent Scoring CR',axis=1)
df1_N
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54234      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54235      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54236      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54238      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54239      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54240      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# ...

# %%
df2=df1[['Regents Exam', 'Mean Score','School Name']]
df2
# Out:
#                Regents Exam Mean Score                     School Name
# 0       Common Core Algebra          s  P.S. 034 Franklin D. Roosevelt
# 1        Living Environment       77.9  P.S. 034 Franklin D. Roosevelt
# 2        Living Environment         74  P.S. 034 Franklin D. Roosevelt
# 19478   Common Core Algebra          s  P.S. 034 Franklin D. Roosevelt
# 19479   Common Core Algebra          s  P.S. 034 Franklin D. Roosevelt
# 19480    Living Environment       77.9  P.S. 034 Franklin D. Roosevelt
# 19481    Living Environment         74  P.S. 034 Franklin D. Roosevelt
# 54234   Common Core Algebra          s  P.S. 034 Franklin D. Roosevelt
# 54235   Common Core Algebra          s  P.S. 034 Franklin D. Roosevelt
# 54236    Living Environment          s  P.S. 034 Franklin D. Roosevelt
# 54237    Living Environment       78.8  P.S. 034 Franklin D. Roosevelt
# 54238    Living Environment          s  P.S. 034 Franklin D. Roosevelt
# ...

# %%
index_def2=df2[df2['Mean Score']=='s'].index
df2_drop=df2.drop(index_def2)
df2_drop
# Out:
#               Regents Exam Mean Score                     School Name
# 1       Living Environment       77.9  P.S. 034 Franklin D. Roosevelt
# 2       Living Environment         74  P.S. 034 Franklin D. Roosevelt
# 19480   Living Environment       77.9  P.S. 034 Franklin D. Roosevelt
# 19481   Living Environment         74  P.S. 034 Franklin D. Roosevelt
# 54237   Living Environment       78.8  P.S. 034 Franklin D. Roosevelt
# 102881  Living Environment         78  P.S. 034 Franklin D. Roosevelt
# 102882  Living Environment       77.9  P.S. 034 Franklin D. Roosevelt
# 139886  Living Environment         80  P.S. 034 Franklin D. Roosevelt
# 139888  Living Environment       75.5  P.S. 034 Franklin D. Roosevelt
# 139892  Living Environment       73.5  P.S. 034 Franklin D. Roosevelt

# %%
df3=df1[df1['Regents Exam']=='Living Environment']
df3_new=df3.drop('Number Scoring CR', axis=1)
df3_N=df3_new.drop('Percent Scoring CR',axis=1)
df3_N
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54236      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54238      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54239      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54240      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102881     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102882     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102883     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102884     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139886     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# ...

# %%
index_def=df3[df3['Mean Score']=='s'].index
df3_drop=df3.drop(index_def3)
df3_drop
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102881     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102882     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139886     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139888     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139892     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 1       Living Environment  2015            16       77.9
# 2       Living Environment  2016             9         74
# 19480   Living Environment  2015            16       77.9
# ...

# %%
df3_dropnew=df3_drop.drop('Number Scoring CR', axis=1)
df3_dropN=df3_dropnew.drop('Percent Scoring CR',axis=1)
df3_dropN
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102881     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102882     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139886     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139888     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139892     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 1       Living Environment  2015            16       77.9
# 2       Living Environment  2016             9         74
# 19480   Living Environment  2015            16       77.9
# ...

# %%
df3_dropN.count()
# Out:
# School DBN                     10
# School Name                    10
# School Level                   10
# Regents Exam                   10
# Year                           10
# Total Tested                   10
# Mean Score                     10
# Number Scoring Below 65        10
# Percent Scoring Below 65       10
# Number Scoring 65 or Above     10
# Percent Scoring 65 or Above    10
# Number Scoring 80 or Above     10
# Percent Scoring 80 or Above    10
# dtype: int64

# %%
df3_dropN.max()
# Out:
# School DBN                                             01M034
# School Name                    P.S. 034 Franklin D. Roosevelt
# School Level                                              K-8
# Regents Exam                               Living Environment
# Year                                                     2016
# Total Tested                                               16
# Mean Score                                                 80
# Number Scoring Below 65                                     1
# Percent Scoring Below 65                                  6.3
# Number Scoring 65 or Above                                  8
# Percent Scoring 65 or Above                              93.8
# Number Scoring 80 or Above                                  7
# Percent Scoring 80 or Above                                50
# dtype: object

# %%
df3_dropN.plot(kind='scatter',x='Total Tested',y='Mean Score')

plt.show()

# %% [markdown]
# # Original data

# %%
df_original=df[df['Regents Exam'] == 'Living Environment']
df_original
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 5          01M140          P.S. 140 Nathan Straus          K-8
# 6          01M140          P.S. 140 Nathan Straus          K-8
# 7          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212325     84X717            Icahn Charter School          K-8
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
#
#               Regents Exam  Year  Total Tested Mean Score  \
# 1       Living Environment  2015            16       77.9
# 2       Living Environment  2016             9         74
# ...

# %%
index_def_original=df[df['Mean Score']=='s'].index
df_drop_original=df.drop(index_def_original)
df_drop_original
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 5          01M140          P.S. 140 Nathan Straus          K-8
# 6          01M140          P.S. 140 Nathan Straus          K-8
# 7          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
# 212324     84X717            Icahn Charter School          K-8
# 212325     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 1        Living Environment  2015            16       77.9
# 2        Living Environment  2016             9         74
# ...

# %%
df_original_new=df_drop_original.drop('Number Scoring CR', axis=1)
df2_original_N=df_original_new.drop('Percent Scoring CR',axis=1)
df2_original_N
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 5          01M140          P.S. 140 Nathan Straus          K-8
# 6          01M140          P.S. 140 Nathan Straus          K-8
# 7          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
# 212324     84X717            Icahn Charter School          K-8
# 212325     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 1        Living Environment  2015            16       77.9
# 2        Living Environment  2016             9         74
# ...

# %%
df2_original_N.groupby(['School Name'])['Mean Score'].max().sort_values(ascending=False)
# Out:
# School Name
# High School of American Studies at Lehman College    98.7
# Central Park East High School                        98.3
# Bronx High School of Science                         97.6
# Townsend Harris High School                          97.6
# Stuyvesant High School                               97.4
#                                                      ...
# P.S./I.S. 217 Roosevelt Island                       57.4
# Satellite East Middle School                         56.6
# J.H.S. 162 The Willoughby                            56.4
# The Urban Assembly Unison School                       50
# P.S. 165 Ida Posner                                    50
# Name: Mean Score, Length: 965, dtype: object

# %%
df2_original_N.groupby(['School Name'])['Mean Score'].min().sort_values(ascending=False)
# Out:
# School Name
# Vista Academy                                         88.8
# The Christa McAuliffe School\I.S. 187                   88
# Washington Heights Academy                            87.3
# P.S. 161 Pedro Albizu Campos                          86.8
# J.H.S. 185 Edward Bleeker                               86
#                                                       ...
# Transit Tech Career and Technical Education High S    20.8
# Academy of Urban Planning                             20.5
# Life Academy High School for Film and Music           19.1
# DreamYard Preparatory School                          16.1
# Brooklyn High School for Law and Technology             15
# Name: Mean Score, Length: 965, dtype: object

# %%
df2_original_N.count()
# Out:
# School DBN                     137109
# School Name                    137109
# School Level                   137109
# Regents Exam                   137101
# Year                           137109
# Total Tested                   137109
# Mean Score                     137109
# Number Scoring Below 65        137109
# Percent Scoring Below 65       137109
# Number Scoring 65 or Above     137109
# Percent Scoring 65 or Above    137109
# Number Scoring 80 or Above     137109
# Percent Scoring 80 or Above    137109
# dtype: int64

# %%
df2_original_N.plot(kind='scatter',x='Total Tested', y='Mean Score')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Data frame had many 'N/A' and 'S' values that I did not believe I needed so I got rid of them using the function drop for 'N/A'and defining index to then specified the value which was 's'. I did some descriptive analytics by using the functions 'describe', 'count', 'max',and 'min' and did some visualization using matplotlib. For the results I found that the highest mean score was 98.7 from "High School of American Studies at Lehman College" and the lowest mean score was 15 from "Brooklyn High School for Law and Technology".
