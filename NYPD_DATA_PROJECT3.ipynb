# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Datasets/NYPD_Arrest_Data__Year_to_Date__20240102.csv')
df
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0        261209118  01/01/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1        262984267  02/03/2023    515     CONTROLLED SUBSTANCE,SALE 3  117.0
# 2        263664549  02/15/2023    105               STRANGULATION 1ST  106.0
# 3        261345231  01/04/2023    105               STRANGULATION 1ST  106.0
# 4        263536618  02/13/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# ...            ...         ...    ...                             ...    ...
# 170090   270955727  07/07/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 170091   273117887  08/18/2023    681      CHILD, ENDANGERING WELFARE  233.0
# 170092   274301006  09/13/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 170093   269912233  06/15/2023    490    STOLEN PROPERTY 3,POSSESSION  232.0
# 170094   272045762  07/28/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
#
# ...

# %%
pd.set_option('display.max_columns',None) 
pd.set_option('display.max_rows',None)

# %%
df.describe()
# Out:
#          ARREST_KEY          PD_CD          KY_CD  ARREST_PRECINCT  \
# count  1.700950e+05  170095.000000  170082.000000    170095.000000
# mean   2.683705e+08     425.242200     249.766342        63.423569
# std    4.027782e+06     275.312255     148.500439        34.596068
# min    2.611809e+08       2.000000     101.000000         1.000000
# 25%    2.649555e+08     114.000000     113.000000        40.000000
# 50%    2.685036e+08     397.000000     236.000000        62.000000
# 75%    2.718261e+08     705.000000     344.000000       101.000000
# max    2.752350e+08     997.000000     995.000000       123.000000
#
#        JURISDICTION_CODE    X_COORD_CD     Y_COORD_CD       Latitude  \
# count      170095.000000  1.700950e+05  170095.000000  170095.000000
# mean            0.945918  1.005863e+06  208326.176925      40.738196
# std             7.683909  2.152952e+04   29737.941320       0.128134
# min             0.000000  0.000000e+00       0.000000       0.000000
# ...

# %%
df.count()
# Out:
# ARREST_KEY                  170095
# ARREST_DATE                 170095
# PD_CD                       170095
# PD_DESC                     170095
# KY_CD                       170082
# OFNS_DESC                   170095
# LAW_CODE                    170095
# LAW_CAT_CD                  168838
# ARREST_BORO                 170095
# ARREST_PRECINCT             170095
# JURISDICTION_CODE           170095
# AGE_GROUP                   170095
# PERP_SEX                    170095
# PERP_RACE                   170095
# X_COORD_CD                  170095
# Y_COORD_CD                  170095
# Latitude                    170095
# Longitude                   170095
# New Georeferenced Column    170095
# dtype: int64

# %%
df.shape
# Out:
# (170095, 19)

# %%
df.head(300)
# Out:
#      ARREST_KEY ARREST_DATE  PD_CD                                    PD_DESC  \
# 0     261209118  01/01/2023    109                   ASSAULT 2,1,UNCLASSIFIED
# 1     262984267  02/03/2023    515                CONTROLLED SUBSTANCE,SALE 3
# 2     263664549  02/15/2023    105                          STRANGULATION 1ST
# 3     261345231  01/04/2023    105                          STRANGULATION 1ST
# 4     263536618  02/13/2023    109                   ASSAULT 2,1,UNCLASSIFIED
# 5     262030390  01/17/2023    105                          STRANGULATION 1ST
# 6     262362214  01/23/2023    105                          STRANGULATION 1ST
# 7     264579718  03/04/2023    153                                     RAPE 3
# 8     262500981  01/25/2023    729             FORGERY,ETC.,UNCLASSIFIED-FELO
# 9     265281035  03/17/2023    244              BURGLARY,UNCLASSIFIED,UNKNOWN
# 10    262721715  01/30/2023    263                                ARSON 2,3,4
# ...

# %%
df.tail(300)
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD  \
# 169795   274616629  09/19/2023    173
# 169796   274825063  09/22/2023    109
# 169797   272756001  08/12/2023    511
# 169798   269437135  06/07/2023    849
# 169799   270352598  06/25/2023    101
# 169800   270597361  06/29/2023    544
# 169801   271404154  07/16/2023    339
# 169802   273595385  08/29/2023    109
# 169803   273320958  08/23/2023    439
# 169804   269968656  06/17/2023    511
# 169805   269332326  06/05/2023    109
# 169806   271646672  07/20/2023    441
# 169807   273212547  08/21/2023    258
# 169808   274734756  09/21/2023    109
# 169809   274505025  09/15/2023    397
# 169810   271051587  07/09/2023    792
# 169811   269489978  06/07/2023    779
# 169812   270566432  06/29/2023    724
# 169813   274645304  09/19/2023    729
# 169814   270332692  06/24/2023    779
# 169815   274065100  09/07/2023    475
# 169816   269235228  06/03/2023    760
# 169817   271789799  07/24/2023    109
# ...

# %%
df.isnull().sum()
# Out:
# ARREST_KEY                     0
# ARREST_DATE                    0
# PD_CD                          0
# PD_DESC                        0
# KY_CD                         13
# OFNS_DESC                      0
# LAW_CODE                       0
# LAW_CAT_CD                  1257
# ARREST_BORO                    0
# ARREST_PRECINCT                0
# JURISDICTION_CODE              0
# AGE_GROUP                      0
# PERP_SEX                       0
# PERP_RACE                      0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                       0
# Longitude                      0
# New Georeferenced Column       0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1270

# %%
df=df.dropna(how='any',axis=1)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df=df.drop('ARREST_PRECINCT',axis=1)
df=df.drop('JURISDICTION_CODE',axis=1)

# %%
df.columns
# Out:
# Index(['ARREST_DATE', 'PD_DESC', 'OFNS_DESC', 'ARREST_BORO', 'AGE_GROUP',
#        'PERP_SEX', 'PERP_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'New Georeferenced Column'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   ARREST_DATE                      PD_DESC        OFNS_DESC ARREST_BORO  \
# 0  01/01/2023     ASSAULT 2,1,UNCLASSIFIED   FELONY ASSAULT           K
# 1  02/03/2023  CONTROLLED SUBSTANCE,SALE 3  DANGEROUS DRUGS           K
# 2  02/15/2023            STRANGULATION 1ST   FELONY ASSAULT           K
# 3  01/04/2023            STRANGULATION 1ST   FELONY ASSAULT           M
# 4  02/13/2023     ASSAULT 2,1,UNCLASSIFIED   FELONY ASSAULT           K
#
#   AGE_GROUP PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0     45-64        F     BLACK      999335      186085  40.677426 -73.945615
# 1     25-44        M     BLACK     1009318      178259  40.655923 -73.909650
# 2     25-44        M     WHITE      982272      158771  40.602468 -74.007120
# 3     25-44        M     BLACK      999899      238684  40.821797 -73.943457
# 4     25-44        M     BLACK     1001437      183080  40.669175 -73.938042
#
#        New Georeferenced Column
# 0  POINT (-73.945615 40.677426)
# ...

# %%
df=df.rename(columns={'PD_DESC':'Felony_Classification','OFNS_DESC':'Offense Description','ARREST_BORO':'Arrest_Borough',})

# %%
df.head(5)
# Out:
#   ARREST_DATE        Felony_Classification Offense Description Arrest_Borough  \
# 0  01/01/2023     ASSAULT 2,1,UNCLASSIFIED      FELONY ASSAULT              K
# 1  02/03/2023  CONTROLLED SUBSTANCE,SALE 3     DANGEROUS DRUGS              K
# 2  02/15/2023            STRANGULATION 1ST      FELONY ASSAULT              K
# 3  01/04/2023            STRANGULATION 1ST      FELONY ASSAULT              M
# 4  02/13/2023     ASSAULT 2,1,UNCLASSIFIED      FELONY ASSAULT              K
#
#   AGE_GROUP PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0     45-64        F     BLACK      999335      186085  40.677426 -73.945615
# 1     25-44        M     BLACK     1009318      178259  40.655923 -73.909650
# 2     25-44        M     WHITE      982272      158771  40.602468 -74.007120
# 3     25-44        M     BLACK      999899      238684  40.821797 -73.943457
# 4     25-44        M     BLACK     1001437      183080  40.669175 -73.938042
#
#        New Georeferenced Column
# ...

# %%
df_crime=df[df['Offense Description']=='SEX CRIMES']
df_crime.head(25)
# Out:
#     ARREST_DATE           Felony_Classification Offense Description  \
# 66   02/22/2023                    SEXUAL ABUSE          SEX CRIMES
# 84   05/14/2023                    SEXUAL ABUSE          SEX CRIMES
# 135  05/26/2023                    SEXUAL ABUSE          SEX CRIMES
# 144  03/10/2023                SEXUAL ABUSE 3,2          SEX CRIMES
# 185  05/03/2023               FORCIBLE TOUCHING          SEX CRIMES
# 187  02/25/2023      CHILD, ENDANGERING WELFARE          SEX CRIMES
# 230  02/19/2023  OBSCENE MATERIAL - UNDER 17 YE          SEX CRIMES
# 243  04/26/2023               FORCIBLE TOUCHING          SEX CRIMES
# 292  03/17/2023      CHILD, ENDANGERING WELFARE          SEX CRIMES
# 294  01/26/2023                     OBSCENITY 1          SEX CRIMES
# 369  01/20/2023      CHILD, ENDANGERING WELFARE          SEX CRIMES
# 387  02/01/2023      CHILD, ENDANGERING WELFARE          SEX CRIMES
# 389  01/19/2023      CHILD, ENDANGERING WELFARE          SEX CRIMES
# ...

# %%
df_crime.groupby(['Arrest_Borough'])['Offense Description'].count().sort_values(ascending=True)
# Out:
# Arrest_Borough
# S     146
# M     754
# B     850
# K     856
# Q    1295
# Name: Offense Description, dtype: int64

# %%
df_crime.groupby(['Felony_Classification'])['Offense Description'].count().sort_values(ascending=True)
# Out:
# Felony_Classification
# INCEST 3                             3
# SEXUAL MISCONDUCT,DEVIATE            4
# OBSCENITY, PERFORMANCE 3             5
# SODOMY 2                             9
# AGGRAVATED SEXUAL ASBUSE            13
# SEX CRIMES                          13
# OBSCENITY 1                         17
# SEXUAL MISCONDUCT,INTERCOURSE       29
# COURSE OF SEXUAL CONDUCT AGAIN      32
# SODOMY 3                            52
# OBSCENE MATERIAL - UNDER 17 YE      63
# SODOMY 1                            84
# SEXUAL ABUSE                       228
# FORCIBLE TOUCHING                  456
# SEXUAL ABUSE 3,2                   508
# CHILD, ENDANGERING WELFARE        2385
# Name: Offense Description, dtype: int64

# %%
df_crime.groupby(['AGE_GROUP'])['Offense Description'].count().sort_values(ascending=True)
# Out:
# AGE_GROUP
# 65+       101
# <18       120
# 18-24     496
# 45-64     714
# 25-44    2470
# Name: Offense Description, dtype: int64

# %%
df_crime.groupby(['PERP_SEX'])['Offense Description'].count().sort_values(ascending=True)
# Out:
# PERP_SEX
# U      76
# F     901
# M    2924
# Name: Offense Description, dtype: int64

# %%
df_crime.groupby(['PERP_RACE'])['Offense Description'].count().sort_values(ascending=True)
# Out:
# PERP_RACE
# AMERICAN INDIAN/ALASKAN NATIVE      21
# UNKNOWN                             67
# WHITE                              302
# BLACK HISPANIC                     357
# ASIAN / PACIFIC ISLANDER           398
# WHITE HISPANIC                    1284
# BLACK                             1472
# Name: Offense Description, dtype: int64

# %%
df_child=df[df['Felony_Classification']=='CHILD, ENDANGERING WELFARE']
df_child.groupby(['Arrest_Borough'])['Felony_Classification'].count().sort_values(ascending=True)
# Out:
# Arrest_Borough
# S     71
# M    336
# K    507
# B    530
# Q    941
# Name: Felony_Classification, dtype: int64

# %%
df_child.groupby(['AGE_GROUP'])['Felony_Classification'].count().sort_values(ascending=True)
# Out:
# AGE_GROUP
# <18        23
# 65+        29
# 45-64     319
# 18-24     339
# 25-44    1675
# Name: Felony_Classification, dtype: int64

# %%
df_age=df[df['AGE_GROUP']=='25-44']
df_age.groupby(['Offense Description'])['AGE_GROUP'].count().sort_values(ascending=True)
# Out:
# Offense Description
# HOMICIDE-NEGLIGENT-VEHICLE                  1
# ADMINISTRATIVE CODES                        1
# DISRUPTION OF A RELIGIOUS SERV              1
# PARKING OFFENSES                            2
# FELONY SEX CRIMES                           2
# ESCAPE 3                                    2
# KIDNAPPING                                  3
# (null)                                      5
# ANTICIPATORY OFFENSES                       6
# OTHER STATE LAWS (NON PENAL LAW)            6
# HOMICIDE-NEGLIGENT,UNCLASSIFIE             12
# OFFENSES RELATED TO CHILDREN               14
# MOVING INFRACTIONS                         15
# DISORDERLY CONDUCT                         20
# FRAUDULENT ACCOSTING                       22
# CHILD ABANDONMENT/NON SUPPORT              26
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED       31
# ENDAN WELFARE INCOMP                       31
# OFFENSES AGAINST PUBLIC SAFETY             38
# HARRASSMENT 2                              45
# ...

# %%
sns.histplot(df_crime['Arrest_Borough'],color='red').set_title('Sexual Abuse Throughout The Boroughs')
# Out:
# Text(0.5, 1.0, 'Sexual Abuse Throughout The Boroughs')

# %%
sns.histplot(df_crime['AGE_GROUP'],color='GREEN').set_title('Sexual Abuse Per Age Group')
# Out:
# Text(0.5, 1.0, 'Sexual Abuse Per Age Group')

# %%
plt.figure(figsize=(16,16))
sns.histplot(df_crime['PERP_RACE'],color='purple').set_title('Sexual Abuse Per Race')
# Out:
# Text(0.5, 1.0, 'Sexual Abuse Per Race')

# %%
sns.histplot(df_child['Arrest_Borough'],color='red').set_title('Child Abuse Throughout The Boroughs')
# Out:
# Text(0.5, 1.0, 'Child Abuse Throughout The Boroughs')

# %%
sns.histplot(df_child['AGE_GROUP'],color='green').set_title('Child Abuse Per Age Group')
# Out:
# Text(0.5, 1.0, 'Child Abuse Per Age Group')

# %%
plt.figure(figsize=(16,16))
sns.histplot(df_child['PERP_RACE'],color='purple').set_title('Child Abuse Per Race')
# Out:
# Text(0.5, 1.0, 'Child Abuse Per Race')

# %% [markdown]
# CONCLUSION
#
# As shown in the data and visualizations the borough with the highest amount of sex crimes is Queens. The highest category of sex crimes is child sex crimesa and among the highest races for sex crimes are Black and White Hispanic. Lastly, the largest age group for all crimes and sex crimes is 25-44 years old.
